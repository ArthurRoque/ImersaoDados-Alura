# %% [markdown]
# ## Análise inicial da tabela de experimentos

# %%
import pandas as pd
url = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
experimentos = pd.read_csv(url, compression='zip')
experimentos
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %% [markdown]
# Antes de partir para a análise, seria interessante filtrar os elementos e dividi-los por tratamento.

# %%
experimentos_com_droga = experimentos[experimentos["tratamento"] == "com_droga"]
experimentos_com_controle = experimentos[experimentos["tratamento"] == "com_controle"]

# %% [markdown]
# ### Desafio 1 - Por que a classe com controle é tão pequena se comparada com a classe com droga?

# %% [markdown]
# O interesse nos experimentos com controle estava apenas na droga 'cacb2b860'. Pois só ela foi utilizada nesse tipo de experimento.

# %%
experimentos_com_controle["droga"].value_counts(normalize=True)
# Out:
# cacb2b860    1.0
# Name: droga, dtype: float64

# %% [markdown]
# ### Desafio 2 - Plotar as 5 últimas linhas da tabela.

# %%
experimentos.tail()
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %% [markdown]
# ### Desafio 3 - Mostrar a proporção das classes de tratamento.

# %%
proporcao = len(experimentos_com_droga)/len(experimentos_com_controle)
print(f'Os experimentos com drogas é cerca de {round(proporcao,2)} vezes maior que os experimentos com controle.')
# Out:
# Os experimentos com drogas é cerca de 11.76 vezes maior que os experimentos com controle.

# %% [markdown]
# ### Desafio 4 - Quantos tipos de drogas foram investigados?

# %%
print(f'Foram testados {len(experimentos["droga"].unique())} tipos de drogas diferentes')
# Out:
# Foram testados 3289 tipos de drogas diferentes

# %% [markdown]
# ### Desafio 6 - Renomear as colunas removendo o hífen.

# %%
# O desafio 6 foi feito antes do desafio 5 pois é preciso renomear as colunar para facilitar a query.

#JEITO 1
colunas = {}
for coluna in experimentos.columns:
    colunas[coluna] = coluna.replace("-", "")
experimentos.rename(columns=colunas)

#JEITO 2 
experimentos.columns = experimentos.columns.str.replace("-", "")

experimentos
# Out:
#                  id    tratamento  tempo dose      droga      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %% [markdown]
# ### Desafio 5 - Procurar na documentação o método query()

# %% [markdown]
# O método query é um método para filtrar as filas de um dataframe utilizando o parâmetro passado.

# %%
experimentos.query('droga == "87d714366"')
# Out:
#                  id tratamento  tempo dose      droga      g0      g1      g2  \
# 16     id_002fb9c19  com_droga     48   D1  87d714366   8.738  0.1914  2.4380
# 76     id_00cf039a7  com_droga     48   D2  87d714366   4.546  0.4257  0.7670
# 119    id_01534c4ee  com_droga     72   D2  87d714366  10.000 -1.2200  1.5150
# 209    id_0236e3425  com_droga     72   D1  87d714366   3.612 -1.7130  0.0313
# 218    id_024a52260  com_droga     24   D2  87d714366   2.119  0.1098  1.1040
# ...             ...        ...    ...  ...        ...     ...     ...     ...
# 23680  id_fe8abffe0  com_droga     72   D1  87d714366   6.649 -0.4462  1.7370
# 23727  id_ff1d43f96  com_droga     24   D2  87d714366   3.263  1.4620  0.2311
# 23776  id_ff9d0a022  com_droga     24   D2  87d714366   1.227  0.3781  2.8860
# 23791  id_ffd1fd119  com_droga     72   D2  87d714366   5.312  0.4505  1.5320
# 23802  id_fff3976bd  com_droga     24   D1  87d714366   3.289  2.1270  0.9770
#
# ...

# %%
experimentos.query('g0 > 8')
# Out:
#                  id tratamento  tempo dose      droga      g0      g1      g2  \
# 16     id_002fb9c19  com_droga     48   D1  87d714366   8.738  0.1914  2.4380
# 119    id_01534c4ee  com_droga     72   D2  87d714366  10.000 -1.2200  1.5150
# 397    id_04372d73c  com_droga     72   D2  87d714366   8.499  1.9470  2.8640
# 643    id_06834da34  com_droga     48   D1  87d714366   8.157  0.6031  0.7811
# 1015   id_0a69a839d  com_droga     72   D2  87d714366   8.537 -0.5659  3.7690
# ...             ...        ...    ...  ...        ...     ...     ...     ...
# 22901  id_f5e7c8135  com_droga     72   D2  87d714366   8.615  3.4180  3.0920
# 22960  id_f68ea082c  com_droga     48   D1  87d714366   8.019 -1.0780  0.6889
# 22971  id_f6b145dbc  com_droga     72   D1  87d714366   8.057 -0.3999  1.0180
# 23294  id_fa506f72e  com_droga     72   D2  87d714366   8.078  1.0890  1.2610
# 23514  id_fcc6036c1  com_droga     48   D1  87d714366   9.597  1.3650  0.3937
#
# ...

# %% [markdown]
# ### Desafio 7 - Plotagem de gráficos Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# * Gráfico aplitude g0 e g1

# %%
ranges = [f'g0 (de {experimentos["g0"].min()} a {experimentos["g0"].max()})', f'g1 (de {experimentos["g1"].min()} a {experimentos["g1"].max()})']
amplitude = [(experimentos["g0"].max() - experimentos["g0"].min()), (experimentos["g1"].max()- experimentos["g1"].min())]

plt.bar(ranges, amplitude, color="#f34336")

plt.title('Amplitude dos elementos g0 e g1')
plt.show()

# %% [markdown]
# * Gráfico Tipos de tratamento

# %%
experimentos['tratamento'].value_counts().plot.bar(color='#87fd4d', 
                                                   title='Tipos de tratamento', 
                                                   xlabel='TRATAMENTO', 
                                                   ylabel='N° DE EXPERIMENTOS',
                                                   rot=0)
# Out:
# <AxesSubplot:title={'center':'Tipos de tratamento'}, xlabel='TRATAMENTO', ylabel='N° DE EXPERIMENTOS'>

# %% [markdown]
# ### Desafio 8 - Resumo do que você aprendeu com os dados.

# %% [markdown]
# Foram feitos com 3289 drogas diferentes, experimentos em 23814 diferentes culturas de células. O tratamento foi controlado para 7.83% das culturas e nesse tipo de tratamento, apenas uma droga foi testada.
#
# Os experimentos foram divididos em três grupos com a aproximadamente a mesma quantidade (34.64%,32.72%, 32.63%). Em que cada grupo foi submetido a um tempo de experimento diferente (24 horas, 48 horas e 72 horas).
#
# Foram utilizados no experimento duas doses diferentes. 51% das culturas receberam a dose D1 e aproximadamenta 49% a dose D2. Nenhuma recebeu as duas doses.

# %%
experimentos['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
experimentos['tempo'].value_counts(normalize=True)
# Out:
# 48    0.346435
# 72    0.327202
# 24    0.326363
# Name: tempo, dtype: float64

# %%
experimentos['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64
